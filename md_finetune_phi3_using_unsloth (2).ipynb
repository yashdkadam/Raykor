# %% [raw]
# #Please use GPU T4 for running thie notebook

# %%
#@title Install Necessary Libraries:
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.26" trl peft accelerate bitsandbytes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git
#   Cloning https://github.com/unslothai/unsloth.git to c:\users\kadam\appdata\local\temp\pip-install-4jyix499\unsloth_fdcdaf52ffd448179648875de3fa6420
#   Resolved https://github.com/unslothai/unsloth.git to commit 5134a42f0689c0bb69aba12dc668755bdd4b4693
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tyro in c:\users\kadam\appdata\roaming\python\python311\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.4)
# Requirement already satisfied: transformers>=4.38.2 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.41.0)
# Collecting datasets>=2.16.0 (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Using cached datasets-2.19.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: sentencepiece in c:\users\kadam\appdata\roaming\python\python311\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.65.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.0)
# Requirement already satisfied: wheel>=0.42.0 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.43.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in c:\programdata\anaconda3\lib\site-packages (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.13.1)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\kadam\appdata\roaming\python\python311\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.31.0)
# Requirement already satisfied: xxhash in c:\users\kadam\appdata\roaming\python\python311\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\kadam\appdata\roaming\python\python311\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\programdata\anaconda3\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.23.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers>=4.38.2->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2023.10.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from transformers>=4.38.2->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from transformers>=4.38.2->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.3)
# Requirement already satisfied: docstring-parser>=0.14.1 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: typing-extensions>=4.7.0 in c:\programdata\anaconda3\lib\site-packages (from tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.9.0)
# Requirement already satisfied: rich>=11.1.0 in c:\programdata\anaconda3\lib\site-packages (from tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.3.5)
# Requirement already satisfied: shtab>=1.5.6 in c:\users\kadam\appdata\roaming\python\python311\site-packages (from tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19.0->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=11.1.0->tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=11.1.0->tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.15.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2023.3)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1.0->tyro->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Using cached datasets-2.19.1-py3-none-any.whl (542 kB)
# Installing collected packages: datasets
# Successfully installed datasets-2.19.1
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git 'C:\Users\kadam\AppData\Local\Temp\pip-install-4jyix499\unsloth_fdcdaf52ffd448179648875de3fa6420'
#   WARNING: The script datasets-cli.exe is installed in 'C:\Users\kadam\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
#@title Import Necessary Libraries:

from unsloth import FastLanguageModel
import torch
from trl import SFTTrainer
from transformers import TrainingArguments

# %%
#@title Load the Phi-3 Model:


max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.


model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-3-mini-4k-instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)

# %%
#@title Set Up Fine-Tuning Parameters:
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

# %%
#@title Prepare Your Training Data:

alpaca_prompt = """

"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    data = examples['record']
    texts = []
    for data in zip(data):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        # text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        text = data[0] + " " + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("hackint0sh/md_dataset", split = "train")
dataset.select(range(1000))
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %%
dataset['text'].__len__()

# %%
#@title Fine-Tuning with Unsloth:

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 2,
        warmup_steps = 5,
        num_train_epochs = 1,
        # max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)

# %%
#@title Show current memory stats

gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
trainer_stats = trainer.train()

# %%
trainer_stats.metrics

# %%
#@title inference
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "## Project Hypnos: The Impact of a Brief Hypnosis Intervention on Single-limb Dynamic Balance in People With Chronic Ankle Instability"
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
